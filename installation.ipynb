# %%
# !pip install noise
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for noise: filename=noise-1.2.2-cp312-cp312-win_amd64.whl size=31592 sha256=c86db2aa9e5ea2c09318a7c093d72ed513f7547a089c88b3205f03ca92390082
#   Stored in directory: c:\users\bharat\appdata\local\pip\cache\wheels\78\71\a2\47a0c6acdeb8f7a2f4e69067d3c737219e36414136441a1ef8
# Successfully built noise
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
